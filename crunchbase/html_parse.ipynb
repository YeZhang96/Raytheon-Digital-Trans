# %%
from bs4 import BeautifulSoup
import os
import re
from IPython import embed

path = "./htmls/"
html_files = [f for f in os.listdir(path) if f.endswith(".html")]
print(len(html_files))

field_names = ['Announced Date',
 'Price',
 'Acquisition Type',
 'Acquisition Terms',
 'Acquiree Description',
 'Acquiree Last Funding Type',
 'Acquiree Industries',
 'Acquiree Headquarters Location',
 "Acquiree's Estimated Revenue Range",
 "Acquiree's Total Funding Amount",
 "Acquiree Funding Status",
 "Acquiree's Number of Funding Rounds",
 "Acquirer's Description",
 'Acquirer Industries',
 'Acquirer Headquarters Location',
 "Acquirer's Estimated Revenue Range",
 "Acquirer's Total Funding Amount",
 'Acquirer Funding Status',
 "Acquirer's Number of Funding Rounds"]
# Out:
# 158

# %%
field_class_name = re.compile("component--field-formatter.*")

f = open(path+html_files[0])
soup = BeautifulSoup(f, "html.parser")
fields = soup.find_all("span", {"class" : field_class_name})
acq = soup.find_all("div", {"class": "flex-no-grow cb-overflow-ellipsis identifier-label"})

# %%
for index, i in enumerate(fields[34*18-16:35*18]):
    print(field_names[index % len(field_names)])
    print(i["class"])
    print(i.text)
    print()
# Out:
# Announced Date
# ['component--field-formatter', 'field-type-identifier-multi']
#  Norwalk, Connecticut, United States
#
# Price
# ['component--field-formatter', 'field-type-money', 'ng-star-inserted']
# $27,200,000,000
#
# Acquisition Type
# ['component--field-formatter', 'field-type-enum', 'ng-star-inserted']
# M&A
#
# Acquisition Terms
# ['component--field-formatter', 'field-type-integer', 'ng-star-inserted']
# 4
#
# Acquiree Description
# ['component--field-formatter', 'field-type-date_precision', 'ng-star-inserted']
# Oct 2, 2018
#
# Acquiree Last Funding Type
# ['component--field-formatter', 'field-type-money', 'ng-star-inserted']
# $100,000,000
#
# Acquiree Industries
# ['component--field-formatter', 'field-type-enum', 'ng-star-inserted']
# Acquisition
#
# Acquiree Headquarters Location
# ['component--field-formatter', 'field-type-enum', 'ng-star-inserted']
# Cash
#
# Acquiree's Estimated Revenue Range
# ['component--field-formatter', 'field-type-text_long', 'ng-star-inserted']
# ELOQUII offers an online plus size clothing store featuring women's plus size fashion, clothes and accessories.
#
# Acquiree's Total Funding Amount
# ['component--field-formatter', 'field-type-identifier-multi']
#  E-Commerce, Fashion, Lifestyle, Retail, Women's
#
# Acquiree Funding Status
# ['component--field-formatter', 'field-type-identifier-multi']
#  New York, New York, United States
#
# Acquiree's Number of Funding Rounds
# ['component--field-formatter', 'field-type-money', 'ng-star-inserted']
# $25,000,000
#
# Acquirer's Description
# ['component--field-formatter', 'field-type-enum', 'ng-star-inserted']
# M&A
#
# Acquirer Industries
# ['component--field-formatter', 'field-type-integer', 'ng-star-inserted']
# 6
#
# Acquirer Headquarters Location
# ['component--field-formatter', 'field-type-text_long', 'ng-star-inserted']
# Walmart is a multinational retail corporation that operates several chains of discount department and warehouse stores.
#
# Acquirer's Estimated Revenue Range
# ['component--field-formatter', 'field-type-identifier-multi']
#  E-Commerce, Internet, Mobile, Retail, Retail Technology
#
# Acquirer's Total Funding Amount
# ['component--field-formatter', 'field-type-identifier-multi']
#  Bentonville, Arkansas, United States
#
# Acquirer Funding Status
# ['component--field-formatter', 'field-type-money', 'ng-star-inserted']
# —
#
# Acquirer's Number of Funding Rounds
# ['component--field-formatter', 'field-type-enum', 'ng-star-inserted']
# IPO
#
# Announced Date
# ['component--field-formatter', 'field-type-integer', 'ng-star-inserted']
# —
#
# Price
# ['component--field-formatter', 'field-type-date_precision', 'ng-star-inserted']
# Jun 14, 2006
#
# Acquisition Type
# ['component--field-formatter', 'field-type-money', 'ng-star-inserted']
# $174,000,000
#
# Acquisition Terms
# ['component--field-formatter', 'field-type-enum', 'ng-star-inserted']
# Acquisition
#
# Acquiree Description
# ['component--field-formatter', 'field-type-enum', 'ng-star-inserted']
# —
#
# Acquiree Last Funding Type
# ['component--field-formatter', 'field-type-text_long', 'ng-star-inserted']
# Amici is a leading provider of electronic-discovery (e-discovery) services, primarily supporting litigation and regulatory compliance.
#
# Acquiree Industries
# ['component--field-formatter', 'field-type-enum', 'ng-star-inserted']
# —
#
# Acquiree Headquarters Location
# ['component--field-formatter', 'field-type-identifier-multi']
#  Document Preparation, Ediscovery, Service Industry
#
# Acquiree's Estimated Revenue Range
# ['component--field-formatter', 'field-type-identifier-multi']
#  Albany, New York, United States
#
# Acquiree's Total Funding Amount
# ['component--field-formatter', 'field-type-enum', 'ng-star-inserted']
# —
#
# Acquiree Funding Status
# ['component--field-formatter', 'field-type-money', 'ng-star-inserted']
# —
#
# Acquiree's Number of Funding Rounds
# ['component--field-formatter', 'field-type-enum', 'ng-star-inserted']
# M&A
#
# Acquirer's Description
# ['component--field-formatter', 'field-type-integer', 'ng-star-inserted']
# —
#
# Acquirer Industries
# ['component--field-formatter', 'field-type-text_long', 'ng-star-inserted']
# Xerox is a document management technology and services enterprise, producing printing and publishing systems, copiers and fax machines.
#
# Acquirer Headquarters Location
# ['component--field-formatter', 'field-type-identifier-multi']
#  Digital Media, Hardware, Information Technology, Printing, Software

# %%
def parse(soup):
    acq = soup.find_all("div", {"class": "flex-no-grow cb-overflow-ellipsis identifier-label"})
    fields = soup.find_all("span", {"class" : field_class_name})
    data = []
    row_data = []
    count = 0
    i = 0
    while(i < len(fields)):
        field = fields[i]
        field_index = count % len(field_names)
        field_name = field_names[field_index]
        field_type = field["class"][1]
        if (("Range" in field_name or "Type" in field_name) and field_type != "field-type-enum") :
            row_data.append("—")
        else:
            row_data.append(field.text.strip())
            i += 1
        if field_name == field_names[-1]:
            data.append(row_data)
            row_data = []
        count += 1
    if (len(row_data) > 0) :
        data.append(row_data)
    return data

# %%
data = []
data += parse(soup)
import pandas as pd

df = pd.DataFrame(data)
print(df.shape)
df.head(40)
# with open("crunchbase.csv", "w+") as f:

#     # header = "Transaction Name,Acquiree Name,Acquirer Name,"
#     header = ",".join(filed_names)
#     df.to_csv(f, index=False, header=header.split(","))
# Out:
# (50, 19)
#                0                1            2             3  \
# 0   Dec 20, 1999     $733,000,000  Acquisition  Cash & Stock
# 1   Jul 30, 2003      $16,000,000  Acquisition             —
# 2    Aug 4, 2011     $288,500,000  Acquisition          Cash
# 3   Oct 27, 1999                —  Acquisition             —
# 4    Jul 5, 2011     £606,000,000  Acquisition          Cash
# 5    Mar 5, 2012                —  Acquisition             —
# 6   Jul 18, 2016     €164,000,000  Acquisition             —
# 7   May 12, 2015   $4,400,000,000  Acquisition  Cash & Stock
# 8   Aug 20, 2018                —  Acquisition             —
# 9    Dec 3, 1999                —  Acquisition             —
# 10  Jul 22, 2009                —  Acquisition             —
# 11      Jan 1996                —            —             —
# 12  Aug 16, 2017   $1,300,000,000  Acquisition             —
# 13   Mar 7, 2000  $21,000,000,000  Acquisition         Stock
# 14   Nov 2, 2015     $765,000,000  Acquisition             —
# 15  Jun 15, 1999                —  Acquisition             —
# 16  Jun 29, 1999   $1,200,000,000  Acquisition             —
# 17   Oct 1, 2013                —  Acquisition             —
# 18  Jan 20, 2010                —  Acquisition             —
# 19  Mar 14, 2018                —  Acquisition             —
# 20   Apr 2, 2015      $50,000,000  Acquisition             —
# 21  Oct 30, 2015  $23,300,000,000  Acquisition  Cash & Stock
# 22   Aug 8, 2017   $1,580,000,000  Acquisition             —
# 23  Jan 10, 2011                —            —             —
# 24  Jul 28, 2011     $425,000,000  Acquisition             —
# 25  Feb 22, 2012                —  Acquisition             —
# 26  May 14, 2009                —  Acquisition             —
# 27  Feb 22, 2017                —    Acquihire             —
# 28   Aug 6, 2012      $14,000,000  Acquisition          Cash
# 29  Mar 16, 2010      $40,000,000  Acquisition             —
# 30   Oct 3, 2008                —  Acquisition             —
# 31  Jan 12, 2001                —  Acquisition             —
# 32   Feb 8, 2019                —  Acquisition             —
# 33   Oct 2, 2018     $100,000,000  Acquisition          Cash
# 34  Jun 14, 2006     $174,000,000  Acquisition             —
# 35  Oct 26, 2018                —  Acquisition             —
# 36   Feb 1, 2017     $276,000,000  Acquisition  Cash & Stock
# 37  Apr 17, 2012                —            —             —
# 38   Aug 6, 2018                —  Acquisition             —
# 39  May 18, 2011                —  Acquisition             —
#
#                                                     4  5  \
# 0   Signio, Inc. provides payment services connect...  —
# 1   CLC provides Laboratory Information Management...  —
# 2   Schneller designs and manufactures proprietary...  —
# 3   Benzlers is a manufacturer of mechanical power...  —
# 4   Travelex Global Business Payments provides bus...  —
# 5   Infimed, provides software and hardware for me...  —
# 6   Medtech designs, develops and markets a new ge...  —
# 7    AOL is an online service provider and web portal  —
# 8   Automated machine learning to predict failures...  —
# 9   Cam Tool LLC operates as a designer and manufa...  —
# 10  Leasco Equipment Services operates as an equip...  —
# 11  Jumbo Pictures is a company that was acquired ...  —
# 12  Neff is one of the largest and fastest growing...  —
# 13  Network Solutions provides domain registration...  —
# 14               PHARMAQ is a pharmaceutical company.  —
# 15  ATL is an independent research and development...  —
# 16  Wicor controls the state's biggest natural-gas...  —
# 17  Reclip.It is a social discovery site helping u...  —
# 18  IBS, a Xerox Company brings unrivalled experti...  —
# 19  Altra Footwear claims to have introduced “the ...  —
# 20  tenXer offers employees with productivity tool...  —
# 21  Visa Europe is a payment technology business t...  —
# 22  BAMTECH Media provides technology services and...  —
# 23  VasoNova develops, manufactures, and markets m...  —
# 24  Oakleaf Waste Management, LLC offers waste log...  —
# 25  Reliable Environmental Transport has grown int...  —
# 26  Luminary Micro designs, markets and sells ARM ...  —
# 27            Custom character toys via games & apps.  —
# 28                 Blue Reference is a Software firm.  —
# 29  Xorail, Inc. operates as a railway signal desi...  —
# 30  Portland U-Rent-It offers equipment sales, sup...  —
# 31  Honeywell lubrication products include lubrica...  —
# 32  Liquid Metal 3D Printing with Magnetojet techn...  —
# 33  ELOQUII offers an online plus size clothing st...  —
# 34  Amici is a leading provider of electronic-disc...  —
# 35  Howe and Howe Technologies Inc. has become a w...  —
# 36  Social Point is a social game developer provid...  —
# 37  Hotspots.io is a social media analytics startu...  —
# 38  HumediQ focus is on quality assurance systems ...  —
# 39  Sterilin is manufactures and supplies disposab...  —
#
#                                                     6  \
# 0                              Transaction Processing
# 1                  Chemical, Pharmaceutical, Software
# 2                                           Aerospace
# 3                             Machinery Manufacturing
# 4                             B2B, Financial Services
# 5               Hardware, Medical, Software, Wireless
# 6               Health Care, Medical Device, Robotics
# 7   Advertising Platforms, Apps, Content, Content ...
# 8   Information Technology, Predictive Analytics, ...
# 9                             Machinery Manufacturing
# 10                                 Industrial, Rental
# 11                                           Internet
# 12  Building Material, Construction, Manufacturing...
# 13  Advertising, E-Commerce, Security, SEM, SEO, W...
# 14  Biotechnology, Health Care, Manufacturing, The...
# 15                                                  —
# 16                                        Oil and Gas
# 17                  Consumer Reviews, Coupons, Social
# 18                             Information Technology
# 19   Consumer Goods, Shoes, Sporting Goods, Wearables
# 20                  Analytics, Computer, Gamification
# 21         Banking, E-Commerce, Mobile, NFC, Payments
# 22  Advertising, Broadcasting, Digital Media, Inte...
# 23         Health Care, Manufacturing, Medical Device
# 24             Logistics, Recycling, Waste Management
# 25                                     Transportation
# 26               Energy, Manufacturing, Semiconductor
# 27                          3D Printing, Mobile, Toys
# 28                                           Software
# 29  Apps, Construction, Project Management, Teleco...
# 30                             Commercial, Industrial
# 31                            Machinery Manufacturing
# 32  3D Printing, 3D Technology, Industrial Manufac...
# 33    E-Commerce, Fashion, Lifestyle, Retail, Women's
# 34  Document Preparation, Ediscovery, Service Indu...
# 35  Automotive, Consumer Electronics, Electronics,...
# 36                        Gaming, Social, Video Games
# 37                            Analytics, Social Media
# 38                                     Medical Device
# 39        Chemical, Plastics and Rubber Manufacturing
#
#                                             7  8               9   10 11  \
# 0    Mountain View, California, United States  —               —  M&A  —
# 1       Frechen, Nordrhein-Westfalen, Germany  —               —  M&A  —
# 2                   Kent, Ohio, United States  —               —  M&A  —
# 3              Helsingborg, Skane Lan, Sweden  —               —  M&A  —
# 4             London, England, United Kingdom  —               —  M&A  —
# 5        Liverpool, Liverpool, United Kingdom  —               —  M&A  —
# 6                    Le Lez, Bretagne, France  —      €1,500,000  M&A  1
# 7           New York, New York, United States  —  $1,000,000,000  M&A  1
# 8             Atlanta, Georgia, United States  —      $7,625,000  M&A  3
# 9            Detroit, Michigan, United States  —               —  M&A  —
# 10              Marietta, Ohio, United States  —               —  M&A  —
# 11                                          —  —               —  M&A  —
# 12              Miami, Florida, United States  —               —  M&A  1
# 13           Herndon, Virginia, United States  —               —  M&A  2
# 14                         Oslo, Oslo, Norway  —               —  M&A  —
# 15              Aalborg, Nordjylland, Denmark  —               —  M&A  —
# 16        Milwaukee, Wisconsin, United States  —               —  M&A  —
# 17   Mountain View, California, United States  —        $840,000  M&A  2
# 18           Belfast, Belfast, United Kingdom  —               —  M&A  —
# 19                  Orem, Utah, United States  —               —  M&A  —
# 20   San Francisco, California, United States  —      $4,700,000  M&A  2
# 21            London, England, United Kingdom  —               —  M&A  —
# 22          New York, New York, United States  —  $1,000,000,000  M&A  1
# 23      Menlo Park, California, United States  —      $3,494,340  M&A  2
# 24  East Hartford, Connecticut, United States  —     $30,000,000  M&A  1
# 25   Bridgeport, West Virginia, United States  —               —  M&A  —
# 26               Austin, Texas, United States  —     $44,000,000  M&A  3
# 27            London, England, United Kingdom  —      $3,850,000  M&A  4
# 28                                          —  —               —  M&A  —
# 29       Jacksonville, Florida, United States  —               —  M&A  —
# 30       Corpus Christi, Texas, United States  —               —  M&A  —
# 31             Cleveland, Ohio, United States  —               —  M&A  —
# 32         Getzville, New York, United States  —               —  M&A  1
# 33          New York, New York, United States  —     $25,000,000  M&A  6
# 34            Albany, New York, United States  —               —  M&A  —
# 35            Waterboro, Maine, United States  —               —  M&A  —
# 36                Barcelona, Catalonia, Spain  —     $44,711,476  M&A  5
# 37   San Francisco, California, United States  —               —  M&A  —
# 38                  Grünwald, Bayern, Germany  —               —  M&A  —
# 39           Newport, Newport, United Kingdom  —               —  M&A  —
#
#                                                    12  \
# 0   Verisign operates the infrastructure for the ....
# 1   Waters Division creates business advantages fo...
# 2   TransDigm is a global designer, producer, and ...
# 3   Textron Inc. is a multi-industry company that ...
# 4   Western Union provides consumers and businesse...
# 5   Varian Medical Systems is a manufacturer of me...
# 6   Zimmer Biomet designs, develops, manufactures,...
# 7   Verizon Communications is a broadband and tele...
# 8   United Technologies provides a broad range of ...
# 9   Textron Inc. is a multi-industry company that ...
# 10  United Rentals operates as an equipment rental...
# 11  The mission of The Walt Disney Company is to b...
# 12  United Rentals operates as an equipment rental...
# 13  Verisign operates the infrastructure for the ....
# 14    Zoetis provides healthcare services for animal.
# 15  Texas Instruments develops semiconductor and c...
# 16  WEC Energy Group is one of the nation’s larges...
# 17  Walmart is a multinational retail corporation ...
# 18  Xerox is a document management technology and ...
# 19  VF offers a diverse portfolio of iconic outdoo...
# 20  Twitter is a social networking platform that a...
# 21  Visa is an American multinational financial se...
# 22  The mission of The Walt Disney Company is to b...
# 23  Teleflex is a diversified global company, dist...
# 24  Waste Management is a provider of waste and en...
# 25  Waste Management is a provider of waste and en...
# 26  Texas Instruments develops semiconductor and c...
# 27  The mission of The Walt Disney Company is to b...
# 28  Waters Division creates business advantages fo...
# 29  Wabtec Corporation is a global provider of val...
# 30  United Rentals operates as an equipment rental...
# 31  TransDigm is a global designer, producer, and ...
# 32  Xerox is a document management technology and ...
# 33  Walmart is a multinational retail corporation ...
# 34  Xerox is a document management technology and ...
# 35  Textron Inc. is a multi-industry company that ...
# 36  Take-Two Interactive Software is an American p...
# 37  Twitter is a social networking platform that a...
# 38  Varian Medical Systems is a manufacturer of me...
# 39  Thermo Fisher Scientific is the world leader i...
#
#                                                    13  \
# 0   Cyber Security, Information Technology, Infras...
# 1                                       Search Engine
# 2                            Aerospace, Manufacturing
# 3                      Aerospace, Finance, Industrial
# 4                 Internet, Mobile Payments, Payments
# 5          Health Care, Manufacturing, Medical Device
# 6                       Dental, Hardware, Health Care
# 7   Communications Infrastructure, Information Tec...
# 8   Aerospace, Security, Smart Building, Transport...
# 9                      Aerospace, Finance, Industrial
# 10                   Construction, Industrial, Rental
# 11                                          Animation
# 12                   Construction, Industrial, Rental
# 13  Cyber Security, Information Technology, Infras...
# 14        Biotechnology, Health Care, Market Research
# 15                       Computer, DSP, Semiconductor
# 16                          Energy, Energy Efficiency
# 17  E-Commerce, Internet, Mobile, Retail, Retail T...
# 18  Digital Media, Hardware, Information Technolog...
# 19             Fashion, Product Design, Shoes, Sports
# 20   Blogging Platforms, Messaging, SMS, Social Media
# 21             Financial Services, Internet, Payments
# 22                                          Animation
# 23               Health Care, Medical, Medical Device
# 24                                   Waste Management
# 25                                   Waste Management
# 26                       Computer, DSP, Semiconductor
# 27                                          Animation
# 28                                      Search Engine
# 29                            Hardware, Manufacturing
# 30                   Construction, Industrial, Rental
# 31                           Aerospace, Manufacturing
# 32  Digital Media, Hardware, Information Technolog...
# 33  E-Commerce, Internet, Mobile, Retail, Retail T...
# 34  Digital Media, Hardware, Information Technolog...
# 35                     Aerospace, Finance, Industrial
# 36  Online Games, PC Games, Publishing, Software, ...
# 37   Blogging Platforms, Messaging, SMS, Social Media
# 38         Health Care, Manufacturing, Medical Device
# 39        Bioinformatics, Biotechnology, Life Science
#
#                                             14 15               16   17  18
# 0            Bluemont, Virginia, United States  —      $39,311,110  IPO   3
# 1        Milford, Massachusetts, United States  —                —  IPO   —
# 2               Cleveland, Ohio, United States  —     $133,789,999  IPO   1
# 3      Providence, Rhode Island, United States  —                —  IPO   —
# 4           Englewood, Colorado, United States  —                —  IPO   —
# 5         Palo Alto, California, United States  —                —  IPO   —
# 6               Warsaw, Indiana, United States  —   $1,000,000,000  IPO   1
# 7            New York, New York, United States  —  $30,079,814,466  IPO   7
# 8         Hartford, Connecticut, United States  —       $3,500,000  IPO   2
# 9      Providence, Rhode Island, United States  —                —  IPO   —
# 10        Stamford, Connecticut, United States  —                —  IPO   —
# 11    Lake Buena Vista, Florida, United States  —                —  IPO   —
# 12        Stamford, Connecticut, United States  —                —  IPO   —
# 13           Bluemont, Virginia, United States  —      $39,311,110  IPO   3
# 14              Jogeshwari, Maharashtra, India  —                —  IPO   —
# 15                Dallas, Texas, United States  —                —  IPO   —
# 16         Milwaukee, Wisconsin, United States  —                —  IPO   —
# 17        Bentonville, Arkansas, United States  —                —  IPO   —
# 18         Norwalk, Connecticut, United States  —  $27,200,000,000  M&A   4
# 19  Greenwood Village, Colorado, United States  —     $680,611,554  IPO   1
# 20    San Francisco, California, United States  —   $1,460,166,511  IPO  13
# 21    San Francisco, California, United States  —                —  IPO   1
# 22    Lake Buena Vista, Florida, United States  —                —  IPO   —
# 23     Royersford, Pennsylvania, United States  —     $400,000,000  IPO   1
# 24               Houston, Texas, United States  —                —  IPO   —
# 25               Houston, Texas, United States  —                —  IPO   —
# 26                Dallas, Texas, United States  —                —  IPO   —
# 27    Lake Buena Vista, Florida, United States  —                —  IPO   —
# 28       Milford, Massachusetts, United States  —                —  IPO   —
# 29     Wilmerding, Pennsylvania, United States  —                —  IPO   —
# 30        Stamford, Connecticut, United States  —                —  IPO   —
# 31              Cleveland, Ohio, United States  —     $133,789,999  IPO   1
# 32         Norwalk, Connecticut, United States  —  $27,200,000,000  M&A   4
# 33        Bentonville, Arkansas, United States  —                —  IPO   —
# 34         Norwalk, Connecticut, United States  —  $27,200,000,000  M&A   4
# 35     Providence, Rhode Island, United States  —                —  IPO   —
# 36           New York, New York, United States  —                —  IPO   —
# 37    San Francisco, California, United States  —   $1,460,166,511  IPO  13
# 38        Palo Alto, California, United States  —                —  IPO   —
# 39       Waltham, Massachusetts, United States  —                —  IPO   —
